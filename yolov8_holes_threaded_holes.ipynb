# %%
pip install ultralytics

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/project_dataset
# Out:
# /content/drive/MyDrive/Colab_Notebooks/project_dataset

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= coco.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Colab_Notebooks/project_dataset/runs/detect/train9/weights/best.pt data=coco.yaml
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab_Notebooks/project_dataset/val/labels.cache... 38 images, 1 backgrounds, 0 corrupt: 100% 39/39 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:05<00:00,  1.83s/it]
#                    all         39        905     0.0191      0.328     0.0291    0.00737
#                  holes         39        745      0.026      0.137     0.0246    0.00714
#         threaded_holes         39        160     0.0122      0.519     0.0336     0.0076
# Speed: 3.6ms preprocess, 80.5ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Colab_Notebooks/project_dataset/runs/detect/train9/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/9 /content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images/Copy of image1_0_1047.jpeg: 192x224 (no detections), 40.8ms
# image 2/9 /content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images/Copy of image1_0_1163.jpeg: 192x224 (no detections), 32.8ms
# image 3/9 /content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images/Copy of image1_0_1185.jpeg: 192x224 (no detections), 34.8ms
# image 4/9 /content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images/Copy of image1_0_1518.jpeg: 192x224 (no detections), 35.8ms
# image 5/9 /content/drive/MyDrive/Colab_Notebooks/project_dataset/test/images/Copy of image1_0_1748.jpeg: 192x224 (no detections), 32.6ms
# ...
